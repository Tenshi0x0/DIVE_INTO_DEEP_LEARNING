# %% [markdown]
# ## Q3
#
# Pseudocode:
#
# ```
# def data_iter(batch_size):
#     while True:
#         X = random_normal(shape=(batch_size, d))
#         y = X @ w + b + noise
#         yield X, y
# ```

# %% [markdown]
# ## Q4
